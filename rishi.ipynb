# %%
#imports
from authorization import get_auth_header, get_token
from requests import get
import json
import pandas as pd

# %% [markdown]
# https://prod.liveshare.vsengsaas.visualstudio.com/join?08C2D31C296BBDC434B7DAF929AA8A622E71

# %%
#write a function to get the top 20 artists in the pop genre using the spotify api example
def get_top_artists():
    #get the token
    token = get_token()
    #get the header
    header = get_auth_header(token)
    #get the url
    url = "https://api.spotify.com/v1/search?q=genre:%22pop%22&type=artist&limit=20"
    #get the response
    response = get(url, headers=header)
    #convert to json
    json_response = response.json()
    #get the artists
    artists = json_response['artists']['items']
    #return the artists
    return artists

# %%
df = pd.json_normalize(get_top_artists())

# %%
def get_song_from_playlist(playlist):
    token = get_token()
    header = get_auth_header(token)
    url = "https://api.spotify.com/v1/playlists/" + playlist + "/tracks"
    response = get(url, headers=header)
    json_response = response.json()
    songs = json_response['items']
    df1 = pd.json_normalize(songs)
    df2 = df1['track.name']
    return pd.DataFrame(df2)

# %%
get_song_from_playlist("37i9dQZF1EIezLFyG0SSkJ")
# Out:
#                                            track.name
# 0                                 Tell It To My Heart
# 1                                     Get Back (ASAP)
# 2                                Ghetto (feat. Thara)
# 3                Fly On The Wings Of Love - Radio Mix
# 4                                         Promiscuous
# 5                                         Hungry Eyes
# 6                                   Get Your Shine On
# 7                    Yeah! (feat. Lil Jon & Ludacris)
# 8                                            浪漫飛行 '07
# 9                                   Murder-Death-Kill
# 10                        Safe 2 Say (The Incredible)
# 11              Like a 24 (feat. T.I. & Liffy Stokes)
# 12                                       Hot In Herre
# 13                                            Gangsta
# 14                                            Pump It
# 15                              Heaven - Extended Mix
# 16                                   Put That S**t Up
# 17                                         In Da Club
# 18                                            TiK ToK
# 19                                                151
# 20                               Going Crazy (Instr.)
# 21                                     Rock Your Body
# 22                                          1.000.000
# 23                                                SOS
# 24             Memories (feat. Kid Cudi) - 2021 Remix
# 25                                  This Anuh Rampin'
# 26                                           Essicati
# 27                                           Maneater
# 28                            Let's Go (Instrumental)
# 29                      WE ARE MUSIC! 〜Album Version〜
# 30                One, Two Step (feat. Missy Elliott)
# 31                                      Direct Maniac
# 32                                  Whatever You Like
# 33                          Mr. Saxobeat - Radio Edit
# 34                                        Going Crazy
# 35    4 Minutes (feat. Justin Timberlake & Timbaland)
# 36       If We Ever Meet Again (Featuring Katy Perry)
# 37                         SexyBack (feat. Timbaland)
# 38                                               Down
# 39                                           Let's Go
# 40                                           She Wolf
# 41                                Stamp On The Ground
# 42                                               Rump
# 43                                         Dundy Lion
# 44                                            Work It
# 45                                      Disco Inferno
# 46                                            Hung Up
# 47                                           Like Dat
# 48  Can't Get You out of My Head - Peggy Gou’s Mid...
# 49                      It's Goin' Down (feat. Nitti)

# %%
playlist_ids = ["37i9dQZF1EIezLFyG0SSkJ", "4vKtucORuHzl3bhnUWMMbq", "54nOF0dt7yuHMBK1cLjFCk",
                  "1q4yqfWq8DQ9k8xvpwjSGb", "66bd2w90q5RXlfUnTIF1W3", "2Hy1V8q07RL4ygQtatadve", 
                  "33P9WHZFJArsEEb0q8zwJD", "3EoStzWMnc93ktTEZYsSD4", "5KlUhhSR7sZOdl8Hxy3Guz", 
                  "6ebBexShOwJOfK9UIdzNIm"]
songs_list = pd.DataFrame()
for i in range (len(playlist_ids)):
    songs_list.add(get_song_from_playlist(playlist_ids[i]))

songs_list
# Out:
# 37i9dQZF1EIezLFyG0SSkJ
# 4vKtucORuHzl3bhnUWMMbq
# 54nOF0dt7yuHMBK1cLjFCk
# 1q4yqfWq8DQ9k8xvpwjSGb
# 66bd2w90q5RXlfUnTIF1W3
# 2Hy1V8q07RL4ygQtatadve
# 33P9WHZFJArsEEb0q8zwJD
# 3EoStzWMnc93ktTEZYsSD4
# 5KlUhhSR7sZOdl8Hxy3Guz
# 6ebBexShOwJOfK9UIdzNIm
# Empty DataFrame
# Columns: []
# Index: []
